# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriel-peresrosa/aprendendoacodar/blob/main/Pandas_Aula5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importado a biblioteta
import pandas as pd

# %%
#leitura dos arquivos
df1 = pd.read_excel("Aracaju.xlsx")
df2 = pd.read_excel("Fortaleza.xlsx")
df3 = pd.read_excel("Natal.xlsx")
df4 = pd.read_excel("Recife.xlsx")
df5 = pd.read_excel("Salvador.xlsx")

# %%
df4.head()
# Out:
#    Cidade       Data  Vendas  LojaID  Qtde
# 0  Recife 2019-01-01  162.61     981     1
# 1  Recife 2019-01-01   11.44     983     1
# 2  Recife 2019-02-10   12.94     983     5
# 3  Recife 2019-02-10  160.54     981     3
# 4  Recife 2019-02-14   19.89     983     7

# %%
df = pd.concat([df1, df2, df3, df4, df5])

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde
# 103  Fortaleza 2019-01-01  142.57    1002     3
# 171      Natal 2019-01-02  136.45    1035     3
# 80      Recife 2019-01-01  114.14     982     8
# 50       Natal 2019-03-08  324.00     854     4
# 43   Fortaleza 2019-01-01  191.52    1004     1

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df["LojaID"] = df["LojaID"].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00   1520     1
# 1  Aracaju 2018-01-01   14.21   1522     6
# 2  Aracaju 2018-01-01   71.55   1520     1
# 3  Aracaju 2018-01-01    3.01   1521     7
# 4  Aracaju 2018-01-01   24.51   1522     8

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df.sample(15)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde
# 47       Natal 2018-03-13  521.00    854     3
# 200      Natal 2019-01-02   41.06   1035     1
# 69   Fortaleza 2019-01-01  216.65   1003     6
# 21    Salvador 2019-01-01   39.72   1035     3
# 74      Recife 2019-01-01   38.79    983     6
# 54   Fortaleza 2019-01-01   16.73   1002     5
# 50   Fortaleza 2019-01-01   33.69   1005     3
# 239   Salvador 2019-01-03  161.41   1037     3
# 20   Fortaleza 2019-01-01   39.68   1003     2
# 182   Salvador 2019-01-02    6.60   1037     2
# 8      Aracaju 2019-01-01   12.16   1523     1
# 62       Natal 2018-02-10  793.00    854     4
# 204      Natal 2019-01-02  151.41   1037     2
# 15   Fortaleza 2019-01-01  195.05   1002     2
# 106   Salvador 2019-01-01  149.19   1035     2

# %%
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08

# %%
df["Receita"].max()
# Out:
# 3544.0

# %%
df["Receita"].min()
# Out:
# 3.34

# %%
df.nlargest(3, "Receita")
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0    853     4   3544.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0

# %%
df.nsmallest(3, "Receita")
# Out:
#       Cidade       Data  Vendas LojaID  Qtde  Receita
# 118  Aracaju 2018-01-01    3.34   1522     1     3.34
# 65    Recife 2019-01-01    4.01    981     1     4.01
# 92     Natal 2019-01-02    4.57   1035     1     4.57

# %%
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
df.sort_values("Receita", ascending=False).head(10)
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0    853     4   3544.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0
# 30  Natal 2018-10-02   856.0    853     4   3424.0
# 41  Natal 2018-05-20   835.0    852     4   3340.0
# 10  Natal 2018-10-27   828.0    852     4   3312.0
# 38  Natal 2018-02-25   828.0    852     4   3312.0
# 69  Natal 2019-03-24   817.0    852     4   3268.0
# 62  Natal 2018-02-10   793.0    854     4   3172.0
# 52  Natal 2018-04-27   778.0    854     4   3112.0

# %%
df["Data"] = df["Data"].astype("int64")

# %%
df.dtypes
# Out:
# Cidade      object
# Data         int64
# Vendas     float64
# LojaID      object
# Qtde         int64
# Receita    float64
# dtype: object

# %%
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
df["Ano_Venda"] = df["Data"].dt.year

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Venda
# 102   Aracaju 2018-01-01    7.29   1523     1     7.29       2018
# 91      Natal 2019-01-02   17.74   1035     1    17.74       2019
# 134  Salvador 2019-03-02  125.90   1036     1   125.90       2019
# 3    Salvador 2019-02-10  176.34   1037     3   529.02       2019
# 0      Recife 2019-01-01  162.61    981     1   162.61       2019

# %%
df["Mes_venda"], df["Dia_venda"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Venda  Mes_venda  \
# 79       Natal 2019-02-28  557.00    852     4  2228.00       2019          2
# 42       Natal 2019-03-02  775.00    854     2  1550.00       2019          3
# 23   Fortaleza 2019-01-01   85.90   1004     5   429.50       2019          1
# 122  Fortaleza 2019-03-02  235.06    983     3   705.18       2019          3
# 6      Aracaju 2018-01-01   35.50   1522     2    71.00       2018          1
#
#      Dia_venda
# 79          28
# 42           2
# 23           1
# 122          2
# 6            1

# %%
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
df["Diferenca_dias"] = df["Data"] - df["Data"].min()

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Venda  Mes_venda  \
# 118    Recife 2019-03-02   17.70    981     5    88.50       2019          3
# 78    Aracaju 2018-01-01  154.85   1522     9  1393.65       2018          1
# 162     Natal 2019-01-02   23.08   1036     2    46.16       2019          1
# 116  Salvador 2019-03-02   41.78   1034     3   125.34       2019          3
# 74      Natal 2019-03-10  303.00    854     3   909.00       2019          3
#
#      Dia_venda diferenca_dias Fiferenca_dias Diferenca_dias
# 118          2       425 days       425 days       425 days
# 78           1         0 days         0 days         0 days
# 162          2       366 days       366 days       366 days
# 116          2       425 days       425 days       425 days
# 74          10       433 days       433 days       433 days

# %%
df.drop(columns=["diferenca_dias"], inplace=True)

# %%
df.drop(columns=["Fiferenca_dias"], inplace=True)

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Venda  Mes_venda  \
# 114   Salvador 2019-03-02   25.52   1034     1    25.52       2019          3
# 83    Salvador 2019-01-01   63.66   1036     2   127.32       2019          1
# 115     Recife 2019-03-02   12.23    981     3    36.69       2019          3
# 88   Fortaleza 2019-01-01   68.60   1004     6   411.60       2019          1
# 130   Salvador 2019-03-02   59.78   1036     1    59.78       2019          3
#
#      Dia_venda Diferenca_dias
# 114          2       425 days
# 83           1       365 days
# 115          2       425 days
# 88           1       365 days
# 130          2       425 days

# %%
df["Trimestre_venda"] = df["Data"].dt.quarter

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Venda  Mes_venda  \
# 103  Fortaleza 2019-01-01  142.57   1002     3   427.71       2019          1
# 186   Salvador 2019-01-02  169.09   1036     2   338.18       2019          1
# 65       Natal 2019-04-05  292.00    852     2   584.00       2019          4
# 95    Salvador 2019-01-01    5.13   1035     1     5.13       2019          1
# 94      Recife 2019-01-01   24.70    982     3    74.10       2019          1
#
#      Dia_venda Diferenca_dias  Trimestre_venda
# 103          1       365 days                1
# 186          2       366 days                1
# 65           5       459 days                2
# 95           1       365 days                1
# 94           1       365 days                1

# %%
vendas_marco_19 = df.loc[(df["Data"].dt.year == 2019) & (df["Data"].dt.month == 3)]

# %%
vendas_marco_19.sample(20)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Venda  Mes_venda  \
# 123  Fortaleza 2019-03-02   20.22    981     6   121.32       2019          3
# 133     Recife 2019-03-02   14.67    980     7   102.69       2019          3
# 109   Salvador 2019-03-02  124.37   1035     1   124.37       2019          3
# 108   Salvador 2019-03-02   11.72   1037     1    11.72       2019          3
# 126  Fortaleza 2019-03-02   41.87    980     8   334.96       2019          3
# 131   Salvador 2019-03-02   63.48   1037     3   190.44       2019          3
# 133  Fortaleza 2019-03-02   14.67    980     7   102.69       2019          3
# 134     Recife 2019-03-02  195.18    980     5   975.90       2019          3
# 140  Fortaleza 2019-03-02  166.89    983     5   834.45       2019          3
# 125   Salvador 2019-03-02   25.00   1037     2    50.00       2019          3
# 116   Salvador 2019-03-02   41.78   1034     3   125.34       2019          3
# ...

# %%
df["LojaID"].value_counts(ascending=False)
# Out:
# LojaID
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1002     30
# 1005     30
# 1523     29
# 852      29
# 854      28
# 1004     28
# 853      26
# 1521     21
# 1003     20
# Name: count, dtype: int64

# %%
df["LojaID"].value_counts(ascending=False).plot.bar()
# Out:
# <Axes: xlabel='LojaID'>

# %%
df["LojaID"].value_counts(ascending=True).plot.barh();

# %%
df.groupby(df["Data"].dt.year)["Receita"].sum().plot.pie()
# Out:
# <Axes: ylabel='Receita'>

# %%
df["Cidade"].value_counts()
# Out:
# Cidade
# Natal        240
# Salvador     240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
df["Cidade"].value_counts().plot.bar(title="Total vendas por cidade")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas");

# %%
df["Cidade"].value_counts().plot.bar(title="Total vendas por cidade", color="red")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas");

# %%
plt.style.use("ggplot")

# %%
df.groupby(df["Mes_venda"])["Qtde"].sum().plot(title = "Total Produtos vendidos X mês", marker="v")
plt.xlabel("Mês")
plt.ylabel("Total Produtos Vendidos")
plt.legend()

# %%
df.groupby(df["Mes_venda"])["Qtde"].sum()
# Out:
# Mes_venda
# 1     2208
# 2      144
# 3      467
# 4       23
# 5       17
# 6       13
# 7       13
# 8        2
# 9       10
# 10      14
# 11       2
# 12       3
# Name: Qtde, dtype: int64

# %%
df_2019 = df[df["Ano_Venda"] == 2019]

# %%
df_2019.groupby(df_2019["Mes_venda"])["Qtde"].sum().plot(marker="v")
plt.xlabel("Mês")
plt.ylabel("Total Produtos Vendidos")
plt.legend()

# %%
#Histograma
plt.hist(df["Qtde"], color="orangered");

# %%
plt.scatter(x=df_2019["Dia_venda"], y=df_2019["Receita"]);

# %%
df_2019.groupby(df_2019["Mes_venda"])["Qtde"].sum().plot(marker="v")
plt.xlabel("Mês")
plt.ylabel("Total Produtos Vendidos")
plt.legend()
plt.savefig("grafico QTDE X MES.png")
